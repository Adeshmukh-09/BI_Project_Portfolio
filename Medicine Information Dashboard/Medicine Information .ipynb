# %%
import pandas as pd
import numpy as np

# %%
med_data = pd.read_csv('D:\\Arjun BI Project Portfolio\\Medicine information dashboard (india) Dataset\\A_Z_medicines_dataset_of_India.csv')
med_data
# Out:
#             id                           name  price(₹)  Is_discontinued  \
# 0            1       Augmentin 625 Duo Tablet    223.42            False
# 1            2            Azithral 500 Tablet    132.36            False
# 2            3               Ascoril LS Syrup    118.00            False
# 3            4           Allegra 120mg Tablet    218.81            False
# 4            5                 Avil 25 Tablet     10.96            False
# ...        ...                            ...       ...              ...
# 253968  253969  Ziyapod 100mg Oral Suspension     62.30            False
# 253969  253970            Zemhart 30mg Tablet     54.00            False
# 253970  253971              Zivex 25mg Tablet     57.00            False
# 253971  253972        ZI Fast 500mg Injection    152.00            False
# 253972  253973      Zyvocol 1% Dusting Powder    110.00            False
#
#                             manufacturer_name       type  \
# ...

# %%
med_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253973 entries, 0 to 253972
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  253973 non-null  int64
#  1   name                253973 non-null  object
#  2   price(₹)            253973 non-null  float64
#  3   Is_discontinued     253973 non-null  bool
#  4   manufacturer_name   253973 non-null  object
#  5   type                253973 non-null  object
#  6   pack_size_label     253973 non-null  object
#  7   short_composition1  253973 non-null  object
#  8   short_composition2  112171 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(6)
# memory usage: 15.7+ MB

# %%
med_data = med_data.drop(columns='id')

# %%
med_data
# Out:
#                                  name  price(₹)  Is_discontinued  \
# 0            Augmentin 625 Duo Tablet    223.42            False
# 1                 Azithral 500 Tablet    132.36            False
# 2                    Ascoril LS Syrup    118.00            False
# 3                Allegra 120mg Tablet    218.81            False
# 4                      Avil 25 Tablet     10.96            False
# ...                               ...       ...              ...
# 253968  Ziyapod 100mg Oral Suspension     62.30            False
# 253969            Zemhart 30mg Tablet     54.00            False
# 253970              Zivex 25mg Tablet     57.00            False
# 253971        ZI Fast 500mg Injection    152.00            False
# 253972      Zyvocol 1% Dusting Powder    110.00            False
#
#                             manufacturer_name       type  \
# 0        Glaxo SmithKline Pharmaceuticals Ltd  allopathy
# 1                 Alembic Pharmaceuticals Ltd  allopathy
# ...

# %%
med_data = med_data.rename(columns={
    'name': 'Product Name',
    'price(₹)' : 'Price',
    'Is_discontinued' : 'Medicine Discontinued',
    'manufacturer_name' : 'Manufacturer Name',
    'type' : 'Type',
    'pack_size_label' : 'Package Type'
})

med_data
# Out:
#                          Product Name   Price  Medicine Discontinued  \
# 0            Augmentin 625 Duo Tablet  223.42                  False
# 1                 Azithral 500 Tablet  132.36                  False
# 2                    Ascoril LS Syrup  118.00                  False
# 3                Allegra 120mg Tablet  218.81                  False
# 4                      Avil 25 Tablet   10.96                  False
# ...                               ...     ...                    ...
# 253968  Ziyapod 100mg Oral Suspension   62.30                  False
# 253969            Zemhart 30mg Tablet   54.00                  False
# 253970              Zivex 25mg Tablet   57.00                  False
# 253971        ZI Fast 500mg Injection  152.00                  False
# 253972      Zyvocol 1% Dusting Powder  110.00                  False
#
#                             Manufacturer Name       Type  \
# 0        Glaxo SmithKline Pharmaceuticals Ltd  allopathy
# ...

# %%
med_data = med_data.fillna({
    'short_composition2': 'N/A'
})

# %%
med_data
# Out:
#                          Product Name   Price  Medicine Discontinued  \
# 0            Augmentin 625 Duo Tablet  223.42                  False
# 1                 Azithral 500 Tablet  132.36                  False
# 2                    Ascoril LS Syrup  118.00                  False
# 3                Allegra 120mg Tablet  218.81                  False
# 4                      Avil 25 Tablet   10.96                  False
# ...                               ...     ...                    ...
# 253968  Ziyapod 100mg Oral Suspension   62.30                  False
# 253969            Zemhart 30mg Tablet   54.00                  False
# 253970              Zivex 25mg Tablet   57.00                  False
# 253971        ZI Fast 500mg Injection  152.00                  False
# 253972      Zyvocol 1% Dusting Powder  110.00                  False
#
#                             Manufacturer Name       Type  \
# 0        Glaxo SmithKline Pharmaceuticals Ltd  allopathy
# ...

# %%
med_data['Medicine Composition'] = med_data['short_composition1'] + ',' + med_data['short_composition2']

# %%
med_data
# Out:
#                          Product Name   Price  Medicine Discontinued  \
# 0            Augmentin 625 Duo Tablet  223.42                  False
# 1                 Azithral 500 Tablet  132.36                  False
# 2                    Ascoril LS Syrup  118.00                  False
# 3                Allegra 120mg Tablet  218.81                  False
# 4                      Avil 25 Tablet   10.96                  False
# ...                               ...     ...                    ...
# 253968  Ziyapod 100mg Oral Suspension   62.30                  False
# 253969            Zemhart 30mg Tablet   54.00                  False
# 253970              Zivex 25mg Tablet   57.00                  False
# 253971        ZI Fast 500mg Injection  152.00                  False
# 253972      Zyvocol 1% Dusting Powder  110.00                  False
#
#                             Manufacturer Name       Type  \
# 0        Glaxo SmithKline Pharmaceuticals Ltd  allopathy
# ...

# %%
med_data = med_data.drop(['short_composition1','short_composition2'],axis=1)
med_data
# Out:
#                          Product Name   Price  Medicine Discontinued  \
# 0            Augmentin 625 Duo Tablet  223.42                  False
# 1                 Azithral 500 Tablet  132.36                  False
# 2                    Ascoril LS Syrup  118.00                  False
# 3                Allegra 120mg Tablet  218.81                  False
# 4                      Avil 25 Tablet   10.96                  False
# ...                               ...     ...                    ...
# 253968  Ziyapod 100mg Oral Suspension   62.30                  False
# 253969            Zemhart 30mg Tablet   54.00                  False
# 253970              Zivex 25mg Tablet   57.00                  False
# 253971        ZI Fast 500mg Injection  152.00                  False
# 253972      Zyvocol 1% Dusting Powder  110.00                  False
#
#                             Manufacturer Name       Type  \
# 0        Glaxo SmithKline Pharmaceuticals Ltd  allopathy
# ...

# %%
med_data['Product Name'].unique()
# Out:
# array(['Augmentin 625 Duo Tablet', 'Azithral 500 Tablet',
#        'Ascoril LS Syrup', ..., 'Zivex 25mg Tablet',
#        'ZI Fast 500mg Injection', 'Zyvocol 1% Dusting Powder'],
#       dtype=object)

# %%
med_data['Manufacturer Name'].unique()
# Out:
# array(['Glaxo SmithKline Pharmaceuticals Ltd',
#        'Alembic Pharmaceuticals Ltd', 'Glenmark Pharmaceuticals Ltd', ...,
#        'Bliss Life Pharmaceuticals', 'Z Plus Remedies',
#        'Anamiva Life Sciences'], dtype=object)

# %%
med_data.to_csv('medicine_data_Cleaned.csv',index=False)
