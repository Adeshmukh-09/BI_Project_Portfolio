# %%
import pandas as pd
import numpy as np

# %%
dim_date = pd.read_csv('D:\\Arjun BI Project Portfolio\\Atliq Grand Revenue Dashboard\\Input Files\\dim_date.csv')
dim_date
# Out:
#          date  mmm yy week no  day_type
# 0   01-May-22  May 22    W 19   weekend
# 1   02-May-22  May 22    W 19  weekeday
# 2   03-May-22  May 22    W 19  weekeday
# 3   04-May-22  May 22    W 19  weekeday
# 4   05-May-22  May 22    W 19  weekeday
# ..        ...     ...     ...       ...
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend
#
# [92 rows x 4 columns]

# %%
dim_date.head()
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
dim_date.tail()
# Out:
#          date  mmm yy week no  day_type
# 87  27-Jul-22  Jul 22    W 31  weekeday
# 88  28-Jul-22  Jul 22    W 31  weekeday
# 89  29-Jul-22  Jul 22    W 31  weekeday
# 90  30-Jul-22  Jul 22    W 31   weekend
# 91  31-Jul-22  Jul 22    W 32   weekend

# %%
dim_date = dim_date.rename(columns={
    'date' : 'Date',
    'mmm yy' : 'Month Year',
    'week no' : 'Week No.',
    'day_type' : 'Day Type'
})
dim_date
# Out:
#          Date Month Year Week No.  Day Type
# 0   01-May-22     May 22     W 19   weekend
# 1   02-May-22     May 22     W 19  weekeday
# 2   03-May-22     May 22     W 19  weekeday
# 3   04-May-22     May 22     W 19  weekeday
# 4   05-May-22     May 22     W 19  weekeday
# ..        ...        ...      ...       ...
# 87  27-Jul-22     Jul 22     W 31  weekeday
# 88  28-Jul-22     Jul 22     W 31  weekeday
# 89  29-Jul-22     Jul 22     W 31  weekeday
# 90  30-Jul-22     Jul 22     W 31   weekend
# 91  31-Jul-22     Jul 22     W 32   weekend
#
# [92 rows x 4 columns]

# %%
dim_date.to_csv('dim_date_revised.csv',index=False)

# %%
dim_hotels = pd.read_csv('D:\\Arjun BI Project Portfolio\\Atliq Grand Revenue Dashboard\\Input Files\\dim_hotels.csv')
dim_hotels
# Out:
#     property_id  property_name  category       city
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
dim_hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_id    25 non-null     int64
#  1   property_name  25 non-null     object
#  2   category       25 non-null     object
#  3   city           25 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 932.0+ bytes

# %%
dim_hotels = dim_hotels.rename(columns={
    'property_id' : 'Property ID',
    'property_name' : 'Property Name',
    'category' : 'Category',
    'city' : 'City'
})
dim_hotels
# Out:
#     Property ID  Property Name  Category       City
# 0         16558   Atliq Grands    Luxury      Delhi
# 1         16559  Atliq Exotica    Luxury     Mumbai
# 2         16560     Atliq City  Business      Delhi
# 3         16561      Atliq Blu    Luxury      Delhi
# 4         16562      Atliq Bay    Luxury      Delhi
# 5         16563   Atliq Palace  Business      Delhi
# 6         17558   Atliq Grands    Luxury     Mumbai
# 7         17559  Atliq Exotica    Luxury     Mumbai
# 8         17560     Atliq City  Business     Mumbai
# 9         17561      Atliq Blu    Luxury     Mumbai
# 10        17562      Atliq Bay    Luxury     Mumbai
# 11        17563   Atliq Palace  Business     Mumbai
# 12        18558   Atliq Grands    Luxury  Hyderabad
# 13        18559  Atliq Exotica    Luxury  Hyderabad
# 14        18560     Atliq City  Business  Hyderabad
# 15        18561      Atliq Blu    Luxury  Hyderabad
# 16        18562      Atliq Bay    Luxury  Hyderabad
# ...

# %%
dim_hotels.to_csv('dim_hotels_revised.csv',index=False)

# %%
dim_rooms = pd.read_csv('D:\\Arjun BI Project Portfolio\\Atliq Grand Revenue Dashboard\\Input Files\\dim_rooms.csv')
dim_rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
dim_rooms = dim_rooms.rename(columns={
    'room_id' : 'Room ID',
    'room_class' : 'Room Class'
})
dim_rooms
# Out:
#   Room ID    Room Class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
dim_rooms.to_csv('dim_rooms_revised.csv',index=False)

# %%
fact_aggregated_bookings = pd.read_csv('D:\\Arjun BI Project Portfolio\\Atliq Grand Revenue Dashboard\\Input Files\\fact_aggregated_bookings.csv')
fact_aggregated_bookings
# Out:
#       property_id check_in_date room_category  successful_bookings  capacity
# 0           16559      1-May-22           RT1                   25        30
# 1           19562      1-May-22           RT1                   28        30
# 2           19563      1-May-22           RT1                   23        30
# 3           17558      1-May-22           RT1                   13        19
# 4           16558      1-May-22           RT1                   18        19
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13        18
# 9196        16559     31-Jul-22           RT4                   13        18
# 9197        17558     31-Jul-22           RT4                    3         6
# 9198        19563     31-Jul-22           RT4                    3         6
# 9199        17561     31-Jul-22           RT4                    3         4
#
# [9200 rows x 5 columns]

# %%
fact_aggregated_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9200 entries, 0 to 9199
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9200 non-null   int64
#  1   check_in_date        9200 non-null   object
#  2   room_category        9200 non-null   object
#  3   successful_bookings  9200 non-null   int64
#  4   capacity             9200 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 359.5+ KB

# %%
fact_aggregated_bookings = fact_aggregated_bookings.rename(columns={
    'property_id' : 'Property ID',
    'check_in_date' : 'Check In Date',
    'room_category' : 'Room Category',
    'successful_bookings' : 'Successful Bookings',
    'capacity' : 'capacity'
})
fact_aggregated_bookings
# Out:
#       Property ID Check In Date Room Category  Successful Bookings  capacity
# 0           16559      1-May-22           RT1                   25        30
# 1           19562      1-May-22           RT1                   28        30
# 2           19563      1-May-22           RT1                   23        30
# 3           17558      1-May-22           RT1                   13        19
# 4           16558      1-May-22           RT1                   18        19
# ...           ...           ...           ...                  ...       ...
# 9195        16563     31-Jul-22           RT4                   13        18
# 9196        16559     31-Jul-22           RT4                   13        18
# 9197        17558     31-Jul-22           RT4                    3         6
# 9198        19563     31-Jul-22           RT4                    3         6
# 9199        17561     31-Jul-22           RT4                    3         4
#
# [9200 rows x 5 columns]

# %%
fact_aggregated_bookings.to_csv('fact_aggregated_bookings_revised.csv',index=False)

# %%
fact_bookings = pd.read_csv('D:\\Arjun BI Project Portfolio\\Atliq Grand Revenue Dashboard\\Input Files\\fact_bookings.csv')
fact_bookings
# Out:
#                booking_id  property_id booking_date check_in_date  \
# 0        May012216558RT11        16558    4/27/2022      5/1/2022
# 1        May012216558RT12        16558    4/30/2022      5/1/2022
# 2        May012216558RT13        16558    4/28/2022      5/1/2022
# 3        May012216558RT14        16558    4/28/2022      5/1/2022
# 4        May012216558RT15        16558    4/27/2022      5/1/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564    7/29/2022     7/31/2022
# 134586   Jul312217564RT47        17564    7/30/2022     7/31/2022
# 134587   Jul312217564RT48        17564    7/30/2022     7/31/2022
# 134588   Jul312217564RT49        17564    7/29/2022     7/31/2022
# 134589  Jul312217564RT410        17564    7/31/2022     7/31/2022
#
#        checkout_date  no_guests room_category booking_platform  ratings_given  \
# 0           5/2/2022          3           RT1    direct online            1.0
# ...

# %%
fact_bookings.head(15)
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 0    May012216558RT11        16558    4/27/2022      5/1/2022      5/2/2022
# 1    May012216558RT12        16558    4/30/2022      5/1/2022      5/2/2022
# 2    May012216558RT13        16558    4/28/2022      5/1/2022      5/4/2022
# 3    May012216558RT14        16558    4/28/2022      5/1/2022      5/2/2022
# 4    May012216558RT15        16558    4/27/2022      5/1/2022      5/2/2022
# 5    May012216558RT16        16558     5/1/2022      5/1/2022      5/3/2022
# 6    May012216558RT17        16558    4/28/2022      5/1/2022      5/6/2022
# 7    May012216558RT18        16558    4/26/2022      5/1/2022      5/3/2022
# 8    May012216558RT19        16558    4/30/2022      5/1/2022      5/2/2022
# 9   May012216558RT110        16558    4/28/2022      5/1/2022      5/2/2022
# 10  May012216558RT111        16558    4/29/2022      5/1/2022      5/7/2022
# ...

# %%
fact_bookings = fact_bookings.rename(columns={
    'booking_id' : 'Booking ID',
    'property_id' : 'Property ID',
    'booking_date' : 'Booking Date',
    'check_in_date' : 'Check In Date',
    'checkout_date' : 'Check Out Date',
    'no_guests' : 'No. of Guest',
    'room_category' : 'Room Category',
    'booking_platform' : 'Booking Platform',
    'ratings_given' : 'Rating Given',
    'booking_status' : 'Booking Status',
    'revenue_generated' : 'Revenue Generated',
    'revenue_realized' : 'Revenue Realized'
})
fact_bookings
# Out:
#                Booking ID  Property ID Booking Date Check In Date  \
# 0        May012216558RT11        16558    4/27/2022      5/1/2022
# 1        May012216558RT12        16558    4/30/2022      5/1/2022
# 2        May012216558RT13        16558    4/28/2022      5/1/2022
# 3        May012216558RT14        16558    4/28/2022      5/1/2022
# 4        May012216558RT15        16558    4/27/2022      5/1/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564    7/29/2022     7/31/2022
# 134586   Jul312217564RT47        17564    7/30/2022     7/31/2022
# 134587   Jul312217564RT48        17564    7/30/2022     7/31/2022
# 134588   Jul312217564RT49        17564    7/29/2022     7/31/2022
# 134589  Jul312217564RT410        17564    7/31/2022     7/31/2022
#
#        Check Out Date  No. of Guest Room Category Booking Platform  \
# 0            5/2/2022             3           RT1    direct online
# ...

# %%
fact_bookings = fact_bookings.fillna({
    'Rating Given' : 0
})
fact_bookings
# Out:
#                Booking ID  Property ID Booking Date Check In Date  \
# 0        May012216558RT11        16558    4/27/2022      5/1/2022
# 1        May012216558RT12        16558    4/30/2022      5/1/2022
# 2        May012216558RT13        16558    4/28/2022      5/1/2022
# 3        May012216558RT14        16558    4/28/2022      5/1/2022
# 4        May012216558RT15        16558    4/27/2022      5/1/2022
# ...                   ...          ...          ...           ...
# 134585   Jul312217564RT46        17564    7/29/2022     7/31/2022
# 134586   Jul312217564RT47        17564    7/30/2022     7/31/2022
# 134587   Jul312217564RT48        17564    7/30/2022     7/31/2022
# 134588   Jul312217564RT49        17564    7/29/2022     7/31/2022
# 134589  Jul312217564RT410        17564    7/31/2022     7/31/2022
#
#        Check Out Date  No. of Guest Room Category Booking Platform  \
# 0            5/2/2022             3           RT1    direct online
# ...

# %%
fact_bookings.to_csv('fact_bookings_revised.csv',index=False)

# %%
fact_bookings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Booking ID         134590 non-null  object
#  1   Property ID        134590 non-null  int64
#  2   Booking Date       134590 non-null  object
#  3   Check In Date      134590 non-null  object
#  4   Check Out Date     134590 non-null  object
#  5   No. of Guest       134590 non-null  int64
#  6   Room Category      134590 non-null  object
#  7   Booking Platform   134590 non-null  object
#  8   Rating Given       134590 non-null  object
#  9   Booking Status     134590 non-null  object
#  10  Revenue Generated  134590 non-null  int64
#  11  Revenue Realized   134590 non-null  int64
# dtypes: int64(4), object(8)
# memory usage: 12.3+ MB
